# %% [markdown]
# # Romania shape
#
# data from EU: https://www.eea.europa.eu/data-and-maps/data/eea-reference-grids-2/gis-files/romania-shapefile
#
# Plotting th shape of Romania with tiles of 100, 10 and 1 km.
#
# Note that while Romania's shape resembles that of a fish, with head to the left and tail to the right, the tail is very alongated that the real map, as it is showing also the part of the Black Sea that Romania can exploit economically (oil, natural gas, etc).

# %%
import geopandas as gpd

# %%
INPUT_FOLDER_NAME = "/Users/abuzatu/Work/data/geo_spatial/Romania"

# %%
gdf_100 = gpd.read_file(f"{INPUT_FOLDER_NAME}/1/ro_100km.shp")
gdf_100
# Out:
#        CELLCODE  EOFORIGIN  NOFORIGIN  \
# 0   100kmE50N26    5000000    2600000
# 1   100kmE51N24    5100000    2400000
# 2   100kmE51N25    5100000    2500000
# 3   100kmE51N26    5100000    2600000
# 4   100kmE51N27    5100000    2700000
# 5   100kmE52N24    5200000    2400000
# 6   100kmE52N25    5200000    2500000
# 7   100kmE52N26    5200000    2600000
# 8   100kmE52N27    5200000    2700000
# 9   100kmE52N28    5200000    2800000
# 10  100kmE53N23    5300000    2300000
# 11  100kmE53N24    5300000    2400000
# 12  100kmE53N25    5300000    2500000
# 13  100kmE53N26    5300000    2600000
# 14  100kmE53N27    5300000    2700000
# 15  100kmE53N28    5300000    2800000
# 16  100kmE54N23    5400000    2300000
# 17  100kmE54N24    5400000    2400000
# 18  100kmE54N25    5400000    2500000
# 19  100kmE54N26    5400000    2600000
# 20  100kmE54N27    5400000    2700000
# 21  100kmE54N28    5400000    2800000
# 22  100kmE54N29    5400000    2900000
# ...

# %%
gdf_100.plot()
# Out:
# <AxesSubplot:>

# %%
gdf_10 = gpd.read_file(f"{INPUT_FOLDER_NAME}/1/ro_10km.shp")
gdf_10.plot()
# Out:
# <AxesSubplot:>

# %%
gdf_1 = gpd.read_file(f"{INPUT_FOLDER_NAME}/1/ro_1km.shp")
gdf_1.plot()
# Out:
# <AxesSubplot:>
